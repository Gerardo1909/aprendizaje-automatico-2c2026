# %% [markdown]
# # Ejercicios — Introducción - Teoría de la Decisión
#
# - 📘 Explicación: [`../explained/1_intro_teoria_decision.md`](../explained/1_intro_teoria_decision.md)
# - 📓 Notebook de clase: [`../raw/1_intro_teoria_decision.ipynb`](../raw/1_intro_teoria_decision.ipynb)
#
# > Los enunciados están tal cual los dio la cátedra. Las pistas (*centros*) están al final del `.md` explicado.

# %% [markdown]
# ---
#
# ### Ejercicio 1 — Elegir atributos con poder predictivo
#
# dados los siguientes problemas, elegir un conjunto de atributos que consideres que tengan poder predictivo.
#
# 1. Predecir el tiempo de viaje en colectivo de un punto A a un punto B.
# 1. Predecir el rinde de un cultivo.
# 1. Decidir si una operación con una tarjeta de crédito es fraudulenta o no.
# 1. Calcular el consumo de carne en una familia tipo.
# 1. Decidir si un texto fue generado por un gran modelo de lenguaje (LLM) o escrito por un humano.

# %% [markdown]
# **Mi respuesta:**
#
# <!-- 1.1 — Predecir el tiempo de viaje en colectivo de un punto A a un punto B -->
# -
#
# <!-- 1.2 — Predecir el rinde de un cultivo -->
# -
#
# <!-- 1.3 — Decidir si una operación con una tarjeta de crédito es fraudulenta o no -->
# -
#
# <!-- 1.4 — Calcular el consumo de carne en una familia tipo -->
# -
#
# <!-- 1.5 — Decidir si un texto fue generado por un gran modelo de lenguaje (LLM) o escrito por un humano -->
# -

# %% [markdown]
# ---
#
# ### Ejercicio 2 — ¿Aprendizaje automático o no?
#
# decidir cuáles de los siguientes problemas conviene abordarlos con aprendizaje automático y cuáles no.
#
# 1. Decidir si un número es primo.
# 1. Obtener la edad de una persona a partir de su comportamiento en redes sociales.
# 1. Calcular la probabilidad de rotura de un caño en un pozo petrolífero.
# 1. Calcular la ruta más corta entre dos puntos del mapa de una ciudad.
# 1. Decidir el tamaño óptimo para una lata de bebidas dados ciertas restricciones de las dimensiones.
#
#
# ¿Qué otros enfoques se te ocurren?

# %% [markdown]
# **Mi respuesta:**
#
# <!-- 2.1 — Decidir si un número es primo -->
# -
#
# <!-- 2.2 — Obtener la edad de una persona a partir de su comportamiento en redes sociales -->
# -
#
# <!-- 2.3 — Calcular la probabilidad de rotura de un caño en un pozo petrolífero -->
# -
#
# <!-- 2.4 — Calcular la ruta más corta entre dos puntos del mapa de una ciudad -->
# -
#
# <!-- 2.5 — Decidir el tamaño óptimo para una lata de bebidas dados ciertas restricciones de las dimensiones -->
# -
